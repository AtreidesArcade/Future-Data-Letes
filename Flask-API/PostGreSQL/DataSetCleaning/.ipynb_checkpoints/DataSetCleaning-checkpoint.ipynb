# %%
# Import dependencies
import pandas as pd

# %%
#Import athlete csv file for original Kaggle dataset
athlete_events = pd.read_csv('athlete_events.csv')
athlete_events.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
#Import NOC csv file from original Kaggle data set
noc_regions = pd.read_csv('noc_regions.csv')
noc_regions.head()
# Out:
#    NOC      Country                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
#Combine the two datasets
combined_df = pd.merge(athlete_events, noc_regions, on="NOC")
combined_df.head()
# Out:
#      ID           Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 0     1      A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer
# 1     2       A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer
# 2   602  Abudoureheman   M  22.0   182.0    75.0  China  CHN  2000 Summer
# 3  1463      Ai Linuer   M  25.0   160.0    62.0  China  CHN  2004 Summer
# 4  1464      Ai Yanhan   F  14.0   168.0    54.0  China  CHN  2016 Summer
#
#    Year  Season            City       Sport  \
# 0  1992  Summer       Barcelona  Basketball
# 1  2012  Summer          London        Judo
# 2  2000  Summer          Sydney      Boxing
# 3  2004  Summer          Athina   Wrestling
# 4  2016  Summer  Rio de Janeiro    Swimming
#
#                                       Event Medal Country notes
# 0               Basketball Men's Basketball   NaN   China   NaN
# 1              Judo Men's Extra-Lightweight   NaN   China   NaN
# ...

# %%
combined_df = combined_df.drop_duplicates()
combined_df.loc[combined_df["NOC"]=="SGP", "Country"] = "Singapore"
combined_df.loc[combined_df["NOC"]=="ROT", "Country"] = "Refugee Olympic Athletes"
combined_df.loc[combined_df["NOC"]=="UNK", "Country"] = "Unknown"
combined_df.loc[combined_df["NOC"]=="TUV", "Country"] = "Tuvalu"

# %%
#Create combine clean df
olympics_df = combined_df[["ID", "Name", "Sex", "Age", "Height", "Weight", "Country",\
                          "NOC", "Games", "Year", "Season", "City", "Sport", "Event","Medal"]].copy()
olympics_df.head()
# Out:
#      ID           Name Sex   Age  Height  Weight Country  NOC        Games  \
# 0     1      A Dijiang   M  24.0   180.0    80.0   China  CHN  1992 Summer
# 1     2       A Lamusi   M  23.0   170.0    60.0   China  CHN  2012 Summer
# 2   602  Abudoureheman   M  22.0   182.0    75.0   China  CHN  2000 Summer
# 3  1463      Ai Linuer   M  25.0   160.0    62.0   China  CHN  2004 Summer
# 4  1464      Ai Yanhan   F  14.0   168.0    54.0   China  CHN  2016 Summer
#
#    Year  Season            City       Sport  \
# 0  1992  Summer       Barcelona  Basketball
# 1  2012  Summer          London        Judo
# 2  2000  Summer          Sydney      Boxing
# 3  2004  Summer          Athina   Wrestling
# 4  2016  Summer  Rio de Janeiro    Swimming
#
#                                       Event Medal
# 0               Basketball Men's Basketball   NaN
# 1              Judo Men's Extra-Lightweight   NaN
# 2                 Boxing Men's Middleweight   NaN
# ...

# %%
#Sanity check data set
olympics_df.loc[223512,"Name"]
# Out:
# 'Besarion "Besik\'" Vardzelashvili'

# %%
#Fix import error to PostgreSQL 

olympics_df.loc[223512,"Name"] = olympics_df.loc[223512,"Name"].\
replace('Besarion "Besik\'" Vardzelashvili', 'Besarion "Besik" Vardzelashvili')

# %%
olympics_df.to_csv('olympics_data.csv')
